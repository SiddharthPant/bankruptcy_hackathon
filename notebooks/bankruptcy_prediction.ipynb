# %%
import sys 
sys.path.append('..')
from modules.dataset import Dataset, get_null_counts, plot
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading the data

# %% [markdown]
# First of all lets load our data. For this we created a Dataset class which will house our dataframe objects for us. We created functions within the modules to read the data files and split it appropriately.

# %%
data = Dataset()

# %% [markdown]
# ## Null value counts

# %% [markdown]
# The first step we perform in our exploratory data analysis(EDA) is to guage on the amount of _'Not Available'_ values in our dataset. Our __get_empty_cols()__ function gets back a Series of _null_ value counts in the dataframes of each year. Which we can then plot to see it visually. Please note that only columns with more than 100 null values is shown.

# %%
null_counts = get_null_counts(data.data, gt = 100)

# %%
plot(null_counts, figsize=(20,12), totals=[df.shape[0] for df in data.data])
